# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# Modelo de RandomForest para para predição de grade.

# %%
# %run ../src/feature_engineering.py
# %run ../src/model_evaluation.py
# %run ../src/plot.py
# %run ../src/pipeline.py

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline

# %matplotlib inline
#Alterando configurações padrão dos plots
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (20, 60)

# %%
course_df = pd.read_csv('../data/preprocessed/edx_2014_train.csv',low_memory=False)

class RandonForest:
    def provide(self):
        return Pipeline([('scaler', StandardScaler()),
                  ('rfr', RandomForestRegressor(criterion='mae'))])
    

#svr_lin = SVR(kernel='linear', C=1e3)
#svr_poly = SVR(kernel='poly', C=1e3, degree=2)


course_df['grade'] = course_df['grade'].map(lambda g: g if g > 0 else 0)
results, plt = train_evaluate([RandonForest()], course_df, split_criteria='course_id', feature_extractor=feature_extract, 
                              label='grade', evaluation=regression_evaluation, 
                              plots= [scatter_real_vs_pred_subplot, scatter_residual_error_subplot])

plt.show()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# 2019-05-31 08:16:59 Iniciando modelo RandonForest
# 2019-05-31 08:16:59 Iniciando curso CB22x
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-b1caf4287000>", line 16, in <module>
#     plots= [scatter_real_vs_pred_subplot, scatter_residual_error_subplot])
#   File "C:\Users\Marcelo\Documents\Doutorado\Projeto\mooc-data\src\pipeline.py", line 52, in train_evaluate
#     elif provider.sample_size() and course.shape[0] > provider.sample_size():
# AttributeError: 'RandonForest' object has no attribute 'sample_size'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
reform = {(level2_key, level3_key): values
              for level1_key, level2_dict in results.items()
              for level2_key, level3_dict in level2_dict.items()
              for level3_key, values      in level3_dict.items()}

# %%
pd.options.display.float_format = '{:,.4f}'.format
pd.DataFrame(reform, index=['RandomForest']).T
# Out:
#                                  RandomForest
# 2.01x  explained_variance_score        0.8996
#        mean_absolute_error             0.0197
#        mean_squared_error              0.0033
#        r2_score                        0.8995
# 6.002x explained_variance_score        0.9444
#        mean_absolute_error             0.0130
#        mean_squared_error              0.0019
#        r2_score                        0.9444
# 6.00x  explained_variance_score        0.9213
#        mean_absolute_error             0.0097
#        mean_squared_error              0.0012
#        r2_score                        0.9213
# 7.00x  explained_variance_score        0.9296
#        mean_absolute_error             0.0130
#        mean_squared_error              0.0017
#        r2_score                        0.9296
# 8.02x  explained_variance_score        0.9395
#        mean_absolute_error             0.0084
#        mean_squared_error              0.0011
# ...

# %% [raw]
# pd.DataFrame(reform).T
