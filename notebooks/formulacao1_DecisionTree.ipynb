# %% [markdown]
# # Decision Tree

# %% [markdown]
# Modelo de Regressão Linear para predição de SCORE.

# %%
# %run ../src/feature_engineering.py
# %run ../src/model_evaluation.py
# %run ../src/plot.py
# %run ../src/pipeline.py

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.tree import DecisionTreeRegressor

# %matplotlib inline
#Alterando configurações padrão dos plots
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (20, 60)

# %%
course_df = pd.read_csv('../data/preprocessed/edx_2014_train.csv',low_memory=False)

class DecisionTree:
    def provide(self):
        return DecisionTreeRegressor(criterion='mae', max_depth=3)
    
#print([DecisionTree()])

course_df['grade'] = course_df['grade'].map(lambda g: g if g > 0 else 0)
results, plt = train_evaluate([DecisionTree()], course_df, split_criteria='course_id', feature_extractor=feature_extract, 
                              label='grade', evaluation=regression_evaluation, normalize=normalize,
                              plots= [scatter_real_vs_pred_subplot, scatter_residual_error_subplot])

plt.show()
# Out:
# 2019-05-31 08:00:44 Iniciando modelo DecisionTree
# 2019-05-31 08:00:44 Iniciando curso CB22x
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-5040eb97c449> in <module>
#      10 results, plt = train_evaluate([DecisionTree()], course_df, split_criteria='course_id', feature_extractor=feature_extract,
#      11                               label='grade', evaluation=regression_evaluation, normalize=normalize,
# ---> 12                               plots= [scatter_real_vs_pred_subplot, scatter_residual_error_subplot])
#      13
#      14 plt.show()
#
# ~\Documents\Doutorado\Projeto\mooc-data\src\pipeline.py in train_evaluate(model_providers, data, split_criteria, feature_extractor, label, evaluation, normalize, plots, sample, plot_enabled, balance)
#      50             if sample and course.shape[0] > sample:
#      51                 course = course.sample(sample)
# ---> 52             elif provider.sample_size() and course.shape[0] > provider.sample_size():
#      53                 course = course.sample(provider.sample_size())
#      54
#
# AttributeError: 'DecisionTree' object has no attribute 'sample_size'

# %%
reform = {(level2_key, level3_key): values
              for level1_key, level2_dict in results.items()
              for level2_key, level3_dict in level2_dict.items()
              for level3_key, values      in level3_dict.items()}

# %%
pd.DataFrame(reform, index=['DecisionTree']).T
# Out:
#                                  DecisionTree
# 2.01x  explained_variance_score      0.866620
#        mean_absolute_error           0.019420
#        mean_squared_error            0.004457
#        r2_score                      0.863234
# 6.002x explained_variance_score      0.925377
#        mean_absolute_error           0.013400
#        mean_squared_error            0.002569
#        r2_score                      0.924831
# 6.00x  explained_variance_score      0.865462
#        mean_absolute_error           0.011562
#        mean_squared_error            0.002045
#        r2_score                      0.863874
# 7.00x  explained_variance_score      0.889381
#        mean_absolute_error           0.014869
#        mean_squared_error            0.002801
#        r2_score                      0.886103
# 8.02x  explained_variance_score      0.914953
#        mean_absolute_error           0.009322
#        mean_squared_error            0.001596
#        r2_score                      0.914648
# 8.MReV explained_variance_score      0.895148
#        mean_absolute_error           0.012701
#        mean_squared_error            0.002121
#        r2_score                      0.893979
# CB22x  explained_variance_score      0.909770
#        mean_absolute_error           0.004877
#        mean_squared_error            0.000705
#        r2_score                      0.909207
# CS50x  explained_variance_score      1.000000
#        mean_absolute_error           0.000000
#        mean_squared_error            0.000000
#        r2_score                      1.000000
# ER22x  explained_variance_score      0.933184
#        mean_absolute_error           0.009718
#        mean_squared_error            0.001910
#        r2_score                      0.932882
# PH207x explained_variance_score      0.892916
#        mean_absolute_error           0.019218
#        mean_squared_error            0.004628
#        r2_score                      0.891959

# %% [raw]
# pd.DataFrame(reform).T
